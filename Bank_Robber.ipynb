# %% [markdown]
# <a href="https://colab.research.google.com/github/brucesailes/Bank-Robber/blob/main/Bank_Robber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Bank Robber mini project**
#
#
#
# Let's calculate the time it will take for the sheriff to catch the bank robber, considering that the robber has a 5-minute head start.

# %%
import numpy as np
import matplotlib.pyplot as plt

 # Import the necessary libraries. I'm using numpy and matplotlib

# %%
t = np.linspace(0, 40, 1000) # start, finish, n points

# %%
d_r = 2.5 * t # Distance travelled by robber: d = 2.5t

# %%
d_s = 3 * (t - 5) # Distance travelled by sheriff: d = 3(t-5)

# %%
fig, ax = plt.subplots()
plt.title('A Bank Robber Caught')
plt.xlabel('Time(in minutes)')
plt.ylabel('Distance (in km)')
ax.set_xlim([0, 40])
ax.set_ylim([0, 100])
ax.plot(t, d_r, c='green')
ax.plot(t, d_s, c='blue')
plt.axvline(x=30, color='purple', linestyle='--')
_ = plt.axhline(y=75, color='purple', linestyle='--')

# %% [markdown]
# **Once you run this code. What solution did you come up with?**
